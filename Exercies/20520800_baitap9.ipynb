# %% [markdown]
# # **Baseline Code**

# %%
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from keras.models import load_model, Model
import tensorflow as tf
import keras

class LeNetCNN:
  # constructor
  def __init__(self):
    self.model = None

  # Define structure of the CNN
  def build(self, input_dim, use_act=True, use_pool=True):
    input = Input(shape = input_dim) # X dau vao cua minh

    if use_act:
      out = Conv2D(6, (3, 3), padding='same', activation='relu')(input)
    else:
      out = Conv2D(6, (3, 3), padding='same')(input)

    if use_pool:
      out = MaxPooling2D(pool_size=(2, 2), padding="same")(out)

    if use_act:
      out = Conv2D(16, (3, 3), padding='same', activation='relu')(out)
    else:
      out = Conv2D(16, (3, 3), padding='same')(out)
    
    if use_pool:
      out = MaxPooling2D(pool_size=(2, 2), padding="same")(out)

    flat = Flatten()(out)
    
    # These like ANN
    if use_act:
      out = Dense(120, activation='relu', use_bias=True)(flat)
    else:
      out = Dense(120, use_bias=True)(flat)
    
    if use_act: 
      out = Dense(84, activation='relu', use_bias=True)(out)
    else:
      out = Dense(84, use_bias=True)(out)
      
    output = Dense(10, activation='softmax', use_bias=True)(out) # y~ output
    self.model = Model(input, output)
  
  # Train the model
  def train(self, x_train, y_train, x_val, y_val): # x_train chinh la X, y_train chinh la ground-truth
    sgd = keras.optimizers.SGD(learning_rate=0.01)
    adam = keras.optimizers.Adam(learning_rate=0.01)
    self.model.compile(optimizer=sgd, loss = 'categorical_crossentropy', metrics=['accuracy'])
    self.model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 50, batch_size = 128)
  
  # Load model from file
  def load(self, model_file):
    self.model = load_model(model_file)
  
  # save the trained model
  def save(self, model_file):
    self.model.save(model_file)
  
  # Show the architecture of the model
  def summary(self):
    self.model.summary()

  # Test the model with a given input
  def predict(self, x_test):
    return self.model.predict(x_test)

# %%
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
import numpy as np

def onehot(y):
  oh = np.zeros((y.shape[0], 10))
  for i in range(y.shape[0]):
    oh[i, int(y[i])]=1
  return oh

# %%
import numpy as np
def norm_zero_one(x_train):
  min_val = np.min(x_train)
  max_val = np.max(x_train)
  x_train_norm = (x_train-min_val)/(max_val-min_val)
  return x_train_norm

def norm_normal_dist(x_train):
  mean_val = np.mean(x_train)
  std_val = np.std(x_train)
  x_train_norm = (x_train-mean_val)/std_val
  return x_train_norm

# %%
from sklearn import preprocessing
import numpy as np

#enc = preprocessing.OneHotEncoder()

#enc.fit(y_train)

#y_train_oh = enc.transform(y_train).toarray()
#y_train_oh.shape
y_train_oh = onehot(y_train)
y_train_oh.shape

y_test_oh = onehot(y_test)
y_test_oh.shape

x_train_norm = x_train / 255.0
x_test_norm = x_test / 255.0

#x_train_norm = x_train_norm[:,:,:, np.newaxis] # Optional: Convert 60000x28x28 -> 60000x28x28x1
#x_test_norm = x_test_norm[:,:,:, np.newaxis] # Optional: Convert 60000x28x28 -> 60000x28x28x1

# %%
x_train_norm.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# # **Standard CNN**

# %%
cnn = LeNetCNN()
cnn.build((28, 28, 1))
cnn.summary()
cnn.train(x_train_norm, y_train_oh, x_test_norm, y_test_oh)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 6)         60
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 6)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 16)        880
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 120)               94200
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 106,154
# Trainable params: 106,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 6s 7ms/step - loss: 1.9176 - accuracy: 0.4178 - val_loss: 0.6332 - val_accuracy: 0.8259
# Epoch 2/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4142 - accuracy: 0.8747 - val_loss: 0.3221 - val_accuracy: 0.9005
# Epoch 3/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2682 - accuracy: 0.9199 - val_loss: 0.2183 - val_accuracy: 0.9338
# Epoch 4/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2117 - accuracy: 0.9357 - val_loss: 0.1760 - val_accuracy: 0.9472
# Epoch 5/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1723 - accuracy: 0.9481 - val_loss: 0.1563 - val_accuracy: 0.9528
# Epoch 6/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1471 - accuracy: 0.9558 - val_loss: 0.1317 - val_accuracy: 0.9598
# Epoch 7/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1297 - accuracy: 0.9603 - val_loss: 0.1067 - val_accuracy: 0.9672
# Epoch 8/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1131 - accuracy: 0.9657 - val_loss: 0.0999 - val_accuracy: 0.9684
# Epoch 9/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1042 - accuracy: 0.9686 - val_loss: 0.1041 - val_accuracy: 0.9669
# Epoch 10/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0941 - accuracy: 0.9717 - val_loss: 0.0908 - val_accuracy: 0.9697
# Epoch 11/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0867 - accuracy: 0.9733 - val_loss: 0.0904 - val_accuracy: 0.9717
# Epoch 12/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0813 - accuracy: 0.9752 - val_loss: 0.0717 - val_accuracy: 0.9767
# Epoch 13/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0759 - accuracy: 0.9764 - val_loss: 0.0796 - val_accuracy: 0.9733
# Epoch 14/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0717 - accuracy: 0.9778 - val_loss: 0.0689 - val_accuracy: 0.9774
# Epoch 15/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0676 - accuracy: 0.9798 - val_loss: 0.0702 - val_accuracy: 0.9777
# Epoch 16/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0636 - accuracy: 0.9804 - val_loss: 0.0647 - val_accuracy: 0.9793
# Epoch 17/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0623 - accuracy: 0.9811 - val_loss: 0.0645 - val_accuracy: 0.9775
# Epoch 18/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0589 - accuracy: 0.9818 - val_loss: 0.0646 - val_accuracy: 0.9800
# Epoch 19/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0562 - accuracy: 0.9823 - val_loss: 0.0852 - val_accuracy: 0.9733
# Epoch 20/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0540 - accuracy: 0.9829 - val_loss: 0.0644 - val_accuracy: 0.9785
# Epoch 21/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0522 - accuracy: 0.9837 - val_loss: 0.0565 - val_accuracy: 0.9814
# Epoch 22/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0502 - accuracy: 0.9847 - val_loss: 0.0630 - val_accuracy: 0.9801
# Epoch 23/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0486 - accuracy: 0.9850 - val_loss: 0.0607 - val_accuracy: 0.9800
# Epoch 24/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0466 - accuracy: 0.9856 - val_loss: 0.0521 - val_accuracy: 0.9836
# Epoch 25/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0448 - accuracy: 0.9856 - val_loss: 0.0570 - val_accuracy: 0.9815
# Epoch 26/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0441 - accuracy: 0.9865 - val_loss: 0.0503 - val_accuracy: 0.9834
# Epoch 27/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0423 - accuracy: 0.9868 - val_loss: 0.0554 - val_accuracy: 0.9814
# Epoch 28/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0414 - accuracy: 0.9870 - val_loss: 0.0524 - val_accuracy: 0.9827
# Epoch 29/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0397 - accuracy: 0.9874 - val_loss: 0.0516 - val_accuracy: 0.9825
# Epoch 30/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0389 - accuracy: 0.9880 - val_loss: 0.0511 - val_accuracy: 0.9834
# Epoch 31/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0379 - accuracy: 0.9880 - val_loss: 0.0456 - val_accuracy: 0.9847
# Epoch 32/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0366 - accuracy: 0.9884 - val_loss: 0.0480 - val_accuracy: 0.9836
# Epoch 33/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0351 - accuracy: 0.9892 - val_loss: 0.0470 - val_accuracy: 0.9841
# Epoch 34/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0345 - accuracy: 0.9892 - val_loss: 0.0485 - val_accuracy: 0.9842
# Epoch 35/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0333 - accuracy: 0.9897 - val_loss: 0.0488 - val_accuracy: 0.9842
# Epoch 36/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0323 - accuracy: 0.9901 - val_loss: 0.0508 - val_accuracy: 0.9830
# Epoch 37/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0317 - accuracy: 0.9906 - val_loss: 0.0524 - val_accuracy: 0.9832
# Epoch 38/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0306 - accuracy: 0.9909 - val_loss: 0.0539 - val_accuracy: 0.9841
# Epoch 39/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0298 - accuracy: 0.9905 - val_loss: 0.0537 - val_accuracy: 0.9835
# Epoch 40/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0294 - accuracy: 0.9908 - val_loss: 0.0472 - val_accuracy: 0.9850
# Epoch 41/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0286 - accuracy: 0.9913 - val_loss: 0.0483 - val_accuracy: 0.9834
# Epoch 42/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0277 - accuracy: 0.9916 - val_loss: 0.0549 - val_accuracy: 0.9818
# Epoch 43/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0275 - accuracy: 0.9915 - val_loss: 0.0437 - val_accuracy: 0.9852
# Epoch 44/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0265 - accuracy: 0.9919 - val_loss: 0.0485 - val_accuracy: 0.9844
# Epoch 45/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0259 - accuracy: 0.9919 - val_loss: 0.0550 - val_accuracy: 0.9823
# Epoch 46/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0247 - accuracy: 0.9922 - val_loss: 0.0428 - val_accuracy: 0.9863
# Epoch 47/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0243 - accuracy: 0.9927 - val_loss: 0.0451 - val_accuracy: 0.9863
# Epoch 48/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0232 - accuracy: 0.9930 - val_loss: 0.0459 - val_accuracy: 0.9849
# Epoch 49/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0230 - accuracy: 0.9933 - val_loss: 0.0495 - val_accuracy: 0.9841
# Epoch 50/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0228 - accuracy: 0.9927 - val_loss: 0.0497 - val_accuracy: 0.9842

# %% [markdown]
# # **Non Activation Funciton**

# %%
cnn2 = LeNetCNN()
cnn2.build((28, 28, 1), use_act=False)
cnn2.summary()
cnn2.train(x_train_norm, y_train_oh, x_test_norm, y_test_oh)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 6)         60
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 6)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 16)        880
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 16)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_3 (Dense)             (None, 120)               94200
#
#  dense_4 (Dense)             (None, 84)                10164
#
#  dense_5 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 106,154
# Trainable params: 106,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 3s 5ms/step - loss: 0.7715 - accuracy: 0.7823 - val_loss: 0.3081 - val_accuracy: 0.9106
# Epoch 2/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2726 - accuracy: 0.9185 - val_loss: 0.2153 - val_accuracy: 0.9369
# Epoch 3/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2049 - accuracy: 0.9387 - val_loss: 0.1688 - val_accuracy: 0.9517
# Epoch 4/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1641 - accuracy: 0.9525 - val_loss: 0.1371 - val_accuracy: 0.9584
# Epoch 5/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1382 - accuracy: 0.9598 - val_loss: 0.1205 - val_accuracy: 0.9638
# Epoch 6/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1217 - accuracy: 0.9641 - val_loss: 0.1142 - val_accuracy: 0.9640
# Epoch 7/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1099 - accuracy: 0.9676 - val_loss: 0.0998 - val_accuracy: 0.9685
# Epoch 8/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1014 - accuracy: 0.9701 - val_loss: 0.0909 - val_accuracy: 0.9719
# Epoch 9/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0940 - accuracy: 0.9725 - val_loss: 0.0859 - val_accuracy: 0.9720
# Epoch 10/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0888 - accuracy: 0.9732 - val_loss: 0.0797 - val_accuracy: 0.9742
# Epoch 11/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0839 - accuracy: 0.9749 - val_loss: 0.0746 - val_accuracy: 0.9758
# Epoch 12/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0794 - accuracy: 0.9756 - val_loss: 0.0753 - val_accuracy: 0.9751
# Epoch 13/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0757 - accuracy: 0.9773 - val_loss: 0.0700 - val_accuracy: 0.9770
# Epoch 14/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0736 - accuracy: 0.9784 - val_loss: 0.0693 - val_accuracy: 0.9781
# Epoch 15/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0706 - accuracy: 0.9788 - val_loss: 0.0672 - val_accuracy: 0.9788
# Epoch 16/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0675 - accuracy: 0.9798 - val_loss: 0.0660 - val_accuracy: 0.9792
# Epoch 17/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0655 - accuracy: 0.9804 - val_loss: 0.0718 - val_accuracy: 0.9759
# Epoch 18/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0636 - accuracy: 0.9809 - val_loss: 0.0652 - val_accuracy: 0.9783
# Epoch 19/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0611 - accuracy: 0.9816 - val_loss: 0.0599 - val_accuracy: 0.9802
# Epoch 20/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0596 - accuracy: 0.9819 - val_loss: 0.0577 - val_accuracy: 0.9808
# Epoch 21/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0581 - accuracy: 0.9826 - val_loss: 0.0596 - val_accuracy: 0.9794
# Epoch 22/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0567 - accuracy: 0.9827 - val_loss: 0.0578 - val_accuracy: 0.9813
# Epoch 23/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0550 - accuracy: 0.9835 - val_loss: 0.0599 - val_accuracy: 0.9799
# Epoch 24/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0539 - accuracy: 0.9840 - val_loss: 0.0549 - val_accuracy: 0.9808
# Epoch 25/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0529 - accuracy: 0.9837 - val_loss: 0.0581 - val_accuracy: 0.9815
# Epoch 26/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0519 - accuracy: 0.9841 - val_loss: 0.0550 - val_accuracy: 0.9811
# Epoch 27/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0505 - accuracy: 0.9846 - val_loss: 0.0527 - val_accuracy: 0.9823
# Epoch 28/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0499 - accuracy: 0.9849 - val_loss: 0.0552 - val_accuracy: 0.9806
# Epoch 29/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0485 - accuracy: 0.9855 - val_loss: 0.0555 - val_accuracy: 0.9802
# Epoch 30/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0477 - accuracy: 0.9856 - val_loss: 0.0530 - val_accuracy: 0.9830
# Epoch 31/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0473 - accuracy: 0.9856 - val_loss: 0.0502 - val_accuracy: 0.9820
# Epoch 32/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0465 - accuracy: 0.9855 - val_loss: 0.0554 - val_accuracy: 0.9809
# Epoch 33/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0456 - accuracy: 0.9862 - val_loss: 0.0575 - val_accuracy: 0.9810
# Epoch 34/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0448 - accuracy: 0.9864 - val_loss: 0.0533 - val_accuracy: 0.9824
# Epoch 35/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0441 - accuracy: 0.9867 - val_loss: 0.0512 - val_accuracy: 0.9836
# Epoch 36/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0426 - accuracy: 0.9869 - val_loss: 0.0511 - val_accuracy: 0.9831
# Epoch 37/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0427 - accuracy: 0.9868 - val_loss: 0.0524 - val_accuracy: 0.9824
# Epoch 38/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0419 - accuracy: 0.9873 - val_loss: 0.0483 - val_accuracy: 0.9837
# Epoch 39/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0415 - accuracy: 0.9869 - val_loss: 0.0471 - val_accuracy: 0.9834
# Epoch 40/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0405 - accuracy: 0.9878 - val_loss: 0.0491 - val_accuracy: 0.9832
# Epoch 41/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0403 - accuracy: 0.9874 - val_loss: 0.0513 - val_accuracy: 0.9829
# Epoch 42/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0396 - accuracy: 0.9878 - val_loss: 0.0471 - val_accuracy: 0.9828
# Epoch 43/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0391 - accuracy: 0.9880 - val_loss: 0.0509 - val_accuracy: 0.9839
# Epoch 44/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0380 - accuracy: 0.9884 - val_loss: 0.0483 - val_accuracy: 0.9830
# Epoch 45/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0378 - accuracy: 0.9883 - val_loss: 0.0488 - val_accuracy: 0.9838
# Epoch 46/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0377 - accuracy: 0.9885 - val_loss: 0.0466 - val_accuracy: 0.9834
# Epoch 47/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0368 - accuracy: 0.9890 - val_loss: 0.0468 - val_accuracy: 0.9848
# Epoch 48/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0367 - accuracy: 0.9888 - val_loss: 0.0489 - val_accuracy: 0.9820
# Epoch 49/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0359 - accuracy: 0.9892 - val_loss: 0.0488 - val_accuracy: 0.9828
# Epoch 50/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0353 - accuracy: 0.9893 - val_loss: 0.0487 - val_accuracy: 0.9838

# %% [markdown]
# # **Non Pooling Layer**

# %%
cnn3 = LeNetCNN()
cnn3.build((28, 28, 1), use_pool=False)
cnn3.summary()
cnn3.train(x_train_norm, y_train_oh, x_test_norm, y_test_oh)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 6)         60
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 16)        880
#
#  flatten_2 (Flatten)         (None, 12544)             0
#
#  dense_6 (Dense)             (None, 120)               1505400
#
#  dense_7 (Dense)             (None, 84)                10164
#
#  dense_8 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 1,517,354
# Trainable params: 1,517,354
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7958 - accuracy: 0.7667 - val_loss: 0.2667 - val_accuracy: 0.9216
# Epoch 2/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2223 - accuracy: 0.9348 - val_loss: 0.1923 - val_accuracy: 0.9446
# Epoch 3/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1666 - accuracy: 0.9513 - val_loss: 0.1341 - val_accuracy: 0.9616
# Epoch 4/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1381 - accuracy: 0.9598 - val_loss: 0.1179 - val_accuracy: 0.9639
# Epoch 5/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1188 - accuracy: 0.9653 - val_loss: 0.1707 - val_accuracy: 0.9469
# Epoch 6/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1054 - accuracy: 0.9685 - val_loss: 0.0954 - val_accuracy: 0.9701
# Epoch 7/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0938 - accuracy: 0.9711 - val_loss: 0.0947 - val_accuracy: 0.9703
# Epoch 8/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0865 - accuracy: 0.9739 - val_loss: 0.0904 - val_accuracy: 0.9727
# Epoch 9/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0785 - accuracy: 0.9758 - val_loss: 0.0858 - val_accuracy: 0.9720
# Epoch 10/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0732 - accuracy: 0.9785 - val_loss: 0.0845 - val_accuracy: 0.9737
# Epoch 11/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0682 - accuracy: 0.9784 - val_loss: 0.0867 - val_accuracy: 0.9735
# Epoch 12/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0638 - accuracy: 0.9803 - val_loss: 0.0813 - val_accuracy: 0.9764
# Epoch 13/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0594 - accuracy: 0.9815 - val_loss: 0.0741 - val_accuracy: 0.9770
# Epoch 14/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0563 - accuracy: 0.9819 - val_loss: 0.0790 - val_accuracy: 0.9764
# Epoch 15/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0536 - accuracy: 0.9832 - val_loss: 0.0727 - val_accuracy: 0.9772
# Epoch 16/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0514 - accuracy: 0.9839 - val_loss: 0.0759 - val_accuracy: 0.9763
# Epoch 17/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0467 - accuracy: 0.9852 - val_loss: 0.0745 - val_accuracy: 0.9770
# Epoch 18/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0449 - accuracy: 0.9862 - val_loss: 0.0798 - val_accuracy: 0.9756
# Epoch 19/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0418 - accuracy: 0.9865 - val_loss: 0.0732 - val_accuracy: 0.9774
# Epoch 20/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0413 - accuracy: 0.9871 - val_loss: 0.0761 - val_accuracy: 0.9770
# Epoch 21/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0372 - accuracy: 0.9881 - val_loss: 0.0783 - val_accuracy: 0.9768
# Epoch 22/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0348 - accuracy: 0.9894 - val_loss: 0.0724 - val_accuracy: 0.9775
# Epoch 23/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0347 - accuracy: 0.9893 - val_loss: 0.0673 - val_accuracy: 0.9796
# Epoch 24/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0315 - accuracy: 0.9898 - val_loss: 0.0719 - val_accuracy: 0.9791
# Epoch 25/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0303 - accuracy: 0.9907 - val_loss: 0.0785 - val_accuracy: 0.9764
# Epoch 26/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0278 - accuracy: 0.9916 - val_loss: 0.0716 - val_accuracy: 0.9787
# Epoch 27/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0275 - accuracy: 0.9914 - val_loss: 0.0675 - val_accuracy: 0.9797
# Epoch 28/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0267 - accuracy: 0.9917 - val_loss: 0.0731 - val_accuracy: 0.9792
# Epoch 29/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0238 - accuracy: 0.9933 - val_loss: 0.0636 - val_accuracy: 0.9817
# Epoch 30/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0223 - accuracy: 0.9931 - val_loss: 0.0678 - val_accuracy: 0.9810
# Epoch 31/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0215 - accuracy: 0.9933 - val_loss: 0.0823 - val_accuracy: 0.9771
# Epoch 32/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0196 - accuracy: 0.9942 - val_loss: 0.0659 - val_accuracy: 0.9803
# Epoch 33/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0201 - accuracy: 0.9938 - val_loss: 0.0802 - val_accuracy: 0.9778
# Epoch 34/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0186 - accuracy: 0.9945 - val_loss: 0.0763 - val_accuracy: 0.9785
# Epoch 35/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0169 - accuracy: 0.9950 - val_loss: 0.0653 - val_accuracy: 0.9823
# Epoch 36/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0157 - accuracy: 0.9953 - val_loss: 0.0702 - val_accuracy: 0.9816
# Epoch 37/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0158 - accuracy: 0.9953 - val_loss: 0.0717 - val_accuracy: 0.9810
# Epoch 38/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.0719 - val_accuracy: 0.9821
# Epoch 39/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.0721 - val_accuracy: 0.9812
# Epoch 40/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.0739 - val_accuracy: 0.9813
# Epoch 41/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0126 - accuracy: 0.9965 - val_loss: 0.0901 - val_accuracy: 0.9769
# Epoch 42/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0112 - accuracy: 0.9971 - val_loss: 0.0720 - val_accuracy: 0.9811
# Epoch 43/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0108 - accuracy: 0.9971 - val_loss: 0.0703 - val_accuracy: 0.9822
# Epoch 44/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0102 - accuracy: 0.9970 - val_loss: 0.1612 - val_accuracy: 0.9639
# Epoch 45/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0106 - accuracy: 0.9971 - val_loss: 0.0762 - val_accuracy: 0.9807
# Epoch 46/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 0.0762 - val_accuracy: 0.9816
# Epoch 47/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0081 - accuracy: 0.9980 - val_loss: 0.0727 - val_accuracy: 0.9822
# Epoch 48/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0071 - accuracy: 0.9985 - val_loss: 0.0888 - val_accuracy: 0.9789
# Epoch 49/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0064 - accuracy: 0.9985 - val_loss: 0.0800 - val_accuracy: 0.9807
# Epoch 50/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.0778 - val_accuracy: 0.9817

# %% [markdown]
# # **Kết luận**

# %% [markdown]
# > Việc loại bỏ **Activation Function** giảm độ chính xác của mô hình.
#
# > Việc loại bỏ **Pooling Layer** tuy làm mô hình train lâu hơn, nhưng giúp tăng độ chính xác.
